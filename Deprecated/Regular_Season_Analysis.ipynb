# %% [markdown]
# ### Useful import

# %%
import pandas as pd
import numpy as np
import glob
from collections import Counter

# %%
path_summary = "../Data/Players/Regular_Season/Summary/*"

df_summary = []

dictPos = {'Stürmer' : 'Forward',
       'Verteidiger' : 'Defender'}

for file in glob.iglob(path_summary):
    frame = pd.read_csv(file,sep=';')
    frame['Year'] = file[36:41]
    df_summary.append(frame)
    
df_summary = pd.concat(df_summary)
df_summary.replace({"Pos" : dictPos}, inplace=True)
df_summary.set_index(['Spieler','Team','Pos','Year','GP'], inplace=True)
df_summary.sort_index(inplace=True)
df_summary.drop(df_summary.columns[[0]], axis=1, inplace=True)
df_summary.head(5)
# Out:
#                                                     G   A  PTS  P/GP  \
# Spieler        Team              Pos      Year  GP
# Abid Ramzi     SC Bern           Forward  ry/08 33  9  22   31  0.94
# Abplanalp Marc Fribourg-Gottéron Defender ry/08 44  2   4    6  0.14
#                                           ry/09 47  3   3    6  0.13
#                                           ry/10 42  4   1    5  0.12
#                                           ry/11 46  0   8    8  0.17
#
#                                                     PIM Total  +/-
# Spieler        Team              Pos      Year  GP
# Abid Ramzi     SC Bern           Forward  ry/08 33         87    6
# Abplanalp Marc Fribourg-Gottéron Defender ry/08 44          8    3
#                                           ry/09 47         20    0
#                                           ry/10 42         28   -7
#                                           ry/11 46         45   20

# %%
path_shots = "../Data/Players/Regular_Season/Shots/*"

df_shots = []

dictPos = {'Stürmer' : 'Forward',
       'Verteidiger' : 'Defender'}

for file in glob.iglob(path_shots):
    frame = pd.read_csv(file,sep=';')
    frame['Year'] = file[34:39]
    df_shots.append(frame)
    
df_shots = pd.concat(df_shots)
df_shots.replace({"Pos" : dictPos}, inplace=True)
df_shots.set_index(['Spieler','Team','Pos','Year','GP'], inplace=True)
df_shots.sort_index(inplace=True)
df_shots.drop(df_shots.columns[[0]], axis=1, inplace=True)
df_shots.head(5)
# Out:
#                                                     G  SOG     S%  SOG/GP
# Spieler        Team              Pos      Year  GP
# Abid Ramzi     SC Bern           Forward  ts/08 33  9   78  11.54    2.36
# Abplanalp Marc Fribourg-Gottéron Defender ts/08 44  2   18  11.11    0.41
#                                           ts/09 47  3   38   7.89    0.81
#                                           ts/10 42  4   27  14.81    0.64
#                                           ts/11 46  0   39      0    0.85

# %%
path_shootouts = "../Data/Players/Regular_Season/Shootouts/*"

df_shootouts = []

dictPos = {'Stürmer' : 'Forward',
       'Verteidiger' : 'Defender'}

for file in glob.iglob(path_shootouts):
    frame = pd.read_csv(file,sep=';')
    frame['Year'] = file[38:43]
    df_shootouts.append(frame)
    
df_shootouts = pd.concat(df_shootouts)
df_shootouts.replace({"Pos" : dictPos}, inplace=True)
df_shootouts.set_index(['Spieler','Team','Pos','Year','GP'], inplace=True)
df_shootouts.sort_index(inplace=True)
df_shootouts.drop(df_shootouts.columns[[0]], axis=1, inplace=True)
df_shootouts.head(5)
# Out:
#                                                       PS  PSG  PSM  PS%  \
# Spieler          Team              Pos      Year  GP
# Abplanalp Marc   Fribourg-Gottéron Defender ts/13 42   0    0    0    -
#                                             ts/14 39   0    0    0    -
#                                             ts/15 38   0    0    0    -
# Aeschlimann Marc HC Davos          Forward  ts/13 7    0    0    0    -
#                                             ts/14 16   1    1    0  100
#
#                                                       GWG PS
# Spieler          Team              Pos      Year  GP
# Abplanalp Marc   Fribourg-Gottéron Defender ts/13 42       0
#                                             ts/14 39       0
#                                             ts/15 38       0
# Aeschlimann Marc HC Davos          Forward  ts/13 7        0
#                                             ts/14 16       1

# %%
path_goals = "../Data/Players/Regular_Season/goals/*"

df_goals = []

dictPos = {'Stürmer' : 'Forward',
       'Verteidiger' : 'Defender'}

for file in glob.iglob(path_goals):
    frame = pd.read_csv(file,sep=';')
    frame['Year'] = file[34:39]
    df_goals.append(frame)
    
df_goals = pd.concat(df_goals)
df_goals.replace({"Pos" : dictPos}, inplace=True)
df_goals.set_index(['Spieler','Team','Pos','Year','GP'], inplace=True)
df_goals.sort_index(inplace=True)
df_goals.drop(df_goals.columns[[0]], axis=1, inplace=True)
df_goals.head(5)
# Out:
#                                                     G   A  A1  A2  GWG  EQG  \
# Spieler        Team              Pos      Year  GP
# Abid Ramzi     SC Bern           Forward  ls/08 33  9  22  14   8    2    5
# Abplanalp Marc Fribourg-Gottéron Defender ls/08 44  2   4   3   1    0    2
#                                           ls/09 47  3   3   1   2    2    1
#                                           ls/10 42  4   1   0   1    1    4
#                                           ls/11 46  0   8   4   4    0    0
#
#                                                     EQA  PPG  PPA  SHG  SHA
# Spieler        Team              Pos      Year  GP
# Abid Ramzi     SC Bern           Forward  ls/08 33   15    4    7    0    0
# Abplanalp Marc Fribourg-Gottéron Defender ls/08 44    4    0    0    0    0
#                                           ls/09 47    2    2    1    0    0
#                                           ls/10 42    0    0    1    0    0
#                                           ls/11 46    8    0    0    0    0

# %%
path_penalties = "../Data/Players/Regular_Season/penalties/*"

df_penalties = []

dictPos = {'Stürmer' : 'Forward',
       'Verteidiger' : 'Defender'}

for file in glob.iglob(path_penalties):
    frame = pd.read_csv(file,sep=';')
    frame['Year'] = file[38:43]
    df_penalties.append(frame)
    
df_penalties = pd.concat(df_penalties)
df_penalties.replace({"Pos" : dictPos}, inplace=True)
df_penalties.set_index(['Spieler','Team','Pos','Year','GP'], inplace=True)
df_penalties.sort_index(inplace=True)
df_penalties.drop(df_penalties.columns[[0]], axis=1, inplace=True)
df_penalties.head(5)
# Out:
#                                                     PIM Total  2'   5'  10'  \
# Spieler        Team              Pos      Year  GP
# Abid Ramzi     SC Bern           Forward  es/08 33         87   26   1    1
# Abplanalp Marc Fribourg-Gottéron Defender es/08 44          8    4   0    0
#                                           es/09 47         20   10   0    0
#                                           es/10 42         28    9   0    1
#                                           es/11 46         45   10   1    0
#
#                                                     GM  MP
# Spieler        Team              Pos      Year  GP
# Abid Ramzi     SC Bern           Forward  es/08 33   1   0
# Abplanalp Marc Fribourg-Gottéron Defender es/08 44   0   0
#                                           es/09 47   0   0
#                                           es/10 42   0   0
#                                           es/11 46   1   0

# %%
df = pd.concat([df_shots, df_summary, df_goals, df_penalties, df_shootouts], axis=1)
df = df.loc[:,~df.columns.duplicated()]
df = df.reset_index().set_index(['Spieler','Pos','Team','Year'])
df['Number of year'] = 1
df

df.to_csv('../Data/Players/Cleaned_Data/regular_season_clean.csv')

# %%
df.columns
# Out:
# Index(['GP', 'G', 'SOG', 'S%', 'SOG/GP', 'A', 'PTS', 'P/GP', 'PIM Total',
#        '+/-', 'A1', 'A2', 'GWG', 'EQG', 'EQA', 'PPG', 'PPA', 'SHG', 'SHA',
#        '2' ', '5'', '10'', 'GM', 'MP', 'PS', 'PSG', 'PSM', 'PS%', 'GWG PS',
#        'Number of year'],
#       dtype='object')

# %%
df_grouped_player = df.groupby(level=[0]).agg({"GP" : 'sum',
                                            #"G": "sum",
                                            "A" : 'sum',
                                            "Number of year" : 'sum',
                                            "2\' " : 'sum',
                                            "5\'" : 'sum',
                                            "10\'" : 'sum',
                                            "GM" : 'sum',
                                            "PIM Total" : 'sum'})
df_grouped_player.head(10)
# Out:
#                           Number of year   2'      A  PIM Total  10'    GP  \
# Spieler
# Abid Ramzi                             4  26.0  22.0       87.0  1.0   132
# Abplanalp Marc                        32  55.0  35.0      145.0  1.0  1376
# Abplanalp Sandro                       4   1.0   1.0        2.0  0.0    96
# Aeschlimann Marc                      12   0.0  12.0        0.0  0.0   288
# Afanasenkov Dmitry                     4   3.0   5.0        6.0  0.0    56
# Ahlström Philip                        4   0.0   0.0        0.0  0.0    40
# Akerman Johan                          4  16.0  18.0       67.0  1.0   144
# Alatalo Santeri                       16  59.0  34.0      143.0  0.0   728
# Albrecht Yannick-Lennart               4   5.0  12.0       10.0  0.0   196
# Almond Cody                           16  51.0  45.0      157.0  3.0   428
#
#                            5'   GM
# Spieler
# Abid Ramzi                1.0  1.0
# Abplanalp Marc            1.0  1.0
# Abplanalp Sandro          0.0  0.0
# Aeschlimann Marc          0.0  0.0
# Afanasenkov Dmitry        0.0  0.0
# Ahlström Philip           0.0  0.0
# Akerman Johan             1.0  1.0
# Alatalo Santeri           1.0  1.0
# Albrecht Yannick-Lennart  0.0  0.0
# Almond Cody               1.0  1.0

# %%
df_grouped_team = df.groupby(level=[2]).agg({"GP" : 'sum',
                                            "G": "sum",
                                            "A" : 'sum',
                                            "Number of year" : 'sum',
                                            "2\' " : 'sum',
                                            "5\'" : 'sum',
                                            "10\'" : 'sum',
                                            "GM" : 'sum',
                                            "PIM Total" : 'sum'})
df_grouped_team.head(10)
# Out:
#                     Number of year       G     2'        A  PIM Total   10'  \
# Team
# EHC Biel                      1016  1021.0  1850.0  1718.0     4775.0  49.0
# EV Zug                         848  1294.0  2055.0  2179.0     5845.0  75.0
# Fribourg-Gottéron              976  1179.0  1830.0  1995.0     5095.0  66.0
# Genève-Servette HC             968  1144.0  1904.0  1925.0     5568.0  86.0
# HC Ambri-Piotta                972   951.0  1709.0  1567.0     4383.0  53.0
# HC Davos                       980  1338.0  1974.0  1989.0     5458.0  74.0
# HC Lugano                      928  1197.0  1831.0  2028.0     5042.0  61.0
# Kloten Flyers                 1000  1207.0  1950.0  1988.0     5240.0  71.0
# Lausanne HC                    336   324.0   563.0   536.0     1461.0  14.0
# SC Bern                        960  1260.0  1783.0  2220.0     4841.0  55.0
#
#                        GP    5'    GM
# Team
# EHC Biel            31832  21.0  21.0
# EV Zug              31216  37.0  37.0
# Fribourg-Gottéron   31824  27.0  29.0
# Genève-Servette HC  31292  32.0  32.0
# HC Ambri-Piotta     31824  15.0  17.0
# HC Davos            31380  26.0  26.0
# HC Lugano           30984  26.0  30.0
# Kloten Flyers       31876  22.0  24.0
# Lausanne HC         12112   7.0   8.0
# SC Bern             31644  29.0  27.0
